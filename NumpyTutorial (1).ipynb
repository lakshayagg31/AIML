# %%
import numpy as np
a = np.array([1,2,3])

# %%
a
# Out:
# array([1, 2, 3])

# %%
b = np.array([4,6,3])

# %%
b
# Out:
# array([4, 6, 3])

# %%
c=a+b

# %%
c
# Out:
# array([5, 8, 6])

# %%
d =np.array([(1,2,3),(4,5,6)],dtype=float)

# %%
d
# Out:
# array([[1., 2., 3.],
#        [4., 5., 6.]])

# %%
e= d =np.array([(7,2,3),(4,20,6)],dtype=float)

# %%
e
# Out:
# array([[ 7.,  2.,  3.],
#        [ 4., 20.,  6.]])

# %%
f=e+d

# %%
f
# Out:
# array([[14.,  4.,  6.],
#        [ 8., 40., 12.]])

# %%
a.sort()

# %%
a
# Out:
# array([1, 2, 3])

# %%
a = np.array([11,2,33])

# %%
a.sort()

# %%
a
# Out:
# array([ 2, 11, 33])

# %%
d =np.array([(1,2,3),(4,5,6),(8,2,10),(42,50,6)],dtype=float)

# %%
d
# Out:
# array([[ 1.,  2.,  3.],
#        [ 4.,  5.,  6.],
#        [ 8.,  2., 10.],
#        [42., 50.,  6.]])
